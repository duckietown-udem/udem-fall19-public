# %%
import os, sys
module_path = os.path.abspath(os.path.join('..'))
if module_path not in sys.path:
    sys.path.append(module_path)
from utils.helpers import launch_env, wrap_env, view_results_ipython, change_exercise, seedall, force_done, evaluate_policy

import numpy as np
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-3219af9a1efe> in <module>
# ----> 1 from helpers import launch_env, wrap_env, view_results_ipython, change_exercise, seedall, force_done, evaluate_policy
#       2
#       3 import numpy as np
#
# ~/duckietown-mooc/udem-fall19/helpers.py in <module>
#       2 from typing import Tuple
#       3
# ----> 4 import torch
#       5 import random
#       6 import numpy as np
#
# ModuleNotFoundError: No module named 'torch'

# %%
# !docker image ls
# Out:
# REPOSITORY                                                         TAG                   IMAGE ID            CREATED             SIZE
# <none>                                                             <none>                4414bfb0441f        2 months ago        2.79GB
# dummy-org/dummy-repo                                               latest                a13ef8958986        2 months ago        3.86GB
# <none>                                                             <none>                4b0428c992ab        2 months ago        3.86GB
# bhairavmehta95/aido-submissions                                    2019_05_17_12_30_12   83164f9431d2        2 months ago        3.86GB
# bhairavmehta95/aido-submissions                                    2019_05_17_12_12_30   0ea87b11f985        2 months ago        3.48GB
# duckietown/dt-challenges-evaluator                                 v4                    02e5f9bb3381        2 months ago        929MB
# ...

# %% [markdown]
# # Gameplan
#
# - clone Software repo and classical ros baseline (use-local-repo)
# - docker-lf-compose with arg for which tag to pull
# - write a docker image that, on startup, pulls up rqt (ros-kinetic); step 2, can also just mount the duckietown repo
